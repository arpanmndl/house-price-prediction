# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# to show maximum rows in the output window
pd.set_option('display.max_columns', None)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %% [markdown]
# <h1> Training Dataset </h1>

# %% [markdown]
# <h2> A. Exploratory Data Analysis </h2>

# %% [markdown]
# storing training dataset into tr_data variable

# %%
tr_data = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
tr_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# Understanding training dataset

# %%
tr_data.shape
# Out:
# (1460, 81)

# %%
tr_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
tr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# **Things to do:**
# - Missing Values analysis
# - Filtering out Numerical values
#     - Filtering out Discrete variables
#         - Relation b/w Discrete variables and Target Feature
#     - Filtering out Continuous variables
#         - Relation b/w Continuous variables and Target Feature
# - Filtering out Categorical Features
#     - Relation b/w Categorical variables and Target Feature
# - Cardinality of Categorical Features
# - Outliers

# %% [markdown]
# <h3> A.1. Missing Values: </h3>

# %%
# finding out the percentage of missing values each variable have
nan_features = [features for features in tr_data.columns if tr_data[features].isnull().sum() > 1]
for feature in nan_features:
    print(feature, '\t',np.round((tr_data[feature].isnull().mean()*100), 4), '%missing values')
# Out:
# LotFrontage 	 17.7397 %missing values
# Alley 	 93.7671 %missing values
# MasVnrType 	 59.726 %missing values
# MasVnrArea 	 0.5479 %missing values
# BsmtQual 	 2.5342 %missing values
# BsmtCond 	 2.5342 %missing values
# BsmtExposure 	 2.6027 %missing values
# BsmtFinType1 	 2.5342 %missing values
# BsmtFinType2 	 2.6027 %missing values
# FireplaceQu 	 47.2603 %missing values
# GarageType 	 5.5479 %missing values
# GarageYrBlt 	 5.5479 %missing values
# GarageFinish 	 5.5479 %missing values
# GarageQual 	 5.5479 %missing values
# GarageCond 	 5.5479 %missing values
# PoolQC 	 99.5205 %missing values
# Fence 	 80.7534 %missing values
# MiscFeature 	 96.3014 %missing values

# %%
# relation between missing values and target variable
columns_to_impute = []
for feature in nan_features:
    data = tr_data.copy()
    
    #let's make the variables 1 if the values are missing or 0 otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    #let's calculate the mean SalePrice where information is missing or not
    plt.figure(figsize=(3,2.5))
    data.groupby(feature)['SalePrice'].median().plot.bar()
    a, b = data.groupby(feature)['SalePrice'].median()
    plt.title(feature)
    plt.show()
    
    # storing the variable where the Median SalePrice value is higher for the missing values. So we need to handle these variables with missing values 
    if b > a:
        columns_to_impute.append(feature)

# %%
#cloumns to impute later in the feature engineering senction
for feature in columns_to_impute:
    print(feature)
# Out:
# LotFrontage
# Alley
# MasVnrArea
# Fence
# MiscFeature

# %%
# dropping column "Id" as its unique for every record and thus doesn't have any relation with SalePrice
tr_data = tr_data.drop('Id', axis=1)
tr_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# Now we have explored variables having missing values and also removed a variable that is not contributing to the target variable. Created a list of variables where we have to perform imputation. Next we will analyse Numerical variables...

# %% [markdown]
# <h3> A.2. Numerical Variables & Distribution of Numerical Variables: </h3>

# %%
# first find out the numerical variables and their count

data = tr_data.copy()

#list of numerical variables
num_features = [feature for feature in data.columns if data[feature].dtype != 'O']

#numerical features count
print(f'Numerical Feature Count: {len(num_features)}')

data[num_features].head()
# Out:
# Numerical Feature Count: 37
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# 1      1262         0             0       1262             0             1
# 2       920       866             0       1786             1             0
# 3       961       756             0       1717             1             0
# 4      1145      1053             0       2198             1             0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
# 2         2         1             3             1             6           1
# 3         1         0             3             1             7           1
# 4         2         1             4             1             9           1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       2003.0           2         548           0           61
# 1       1976.0           2         460         298            0
# 2       2001.0           2         608           0           42
# 3       1998.0           3         642           0           35
# 4       2000.0           3         836         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %% [markdown]
# Note that some variable like Date/Time may have dtype as interger (for e.g. - here Year variable has dtype as int). So now we have to filtre this numerical_features list

# %%
# finding the temporal features and storing them in a list
temporal_features = [feature for feature in num_features if 'Yr' in feature or 'Year' in feature]

temporal_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %% [markdown]
# Let's understand the relation between Temporal variable(mainly YearSold) and Target variable(SalePrice)

# %%
# analysing temporal variable

plt.figure(figsize=(6,4))
tr_data.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('YrSold')
plt.ylabel("SalePrice")
plt.title("House Price VS Year Sold")
# Out:
# Text(0.5, 1.0, 'House Price VS Year Sold')

# %% [markdown]
# We can see that with time the SalePrice is dropping. Let's understand the other temporal variables that how they are related to SalePrice.

# %%
# comparing other temporal variables with SalePrice

for feature in temporal_features:
    if feature != 'YrSold':
        data = tr_data.copy()
        # we will capture the difference between year variable and year the house was sold
        data[feature] = data['YrSold'] - data[feature]
        
        plt.figure(figsize=(5,4))
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# We can see that for the other three temporal features - <br>
# <ol>
#     <li><b>YearBuilt</b> - when the house was built the price was the highest and with time it got low</li>
#     <li><b>YearRemodAdd</b> - after remodification the prices are high, with more diff the price also gets low</li>
#     <li><b>GarageYrBlt</b> - same as above two..</li>
# </ol>

# %% [markdown]
# Here we are working with Numerical variables. So we will throw out the temporal variables from the numerical_variable list

# %%
# removing these temporal variables from the list of numerical features
numerical_features = [item for item in num_features if item not in temporal_features]

print(f'Numerical Feature Count: {len(numerical_features)}')
# Out:
# Numerical Feature Count: 33

# %% [markdown]
# Now we will determine the type of the Numerical Feature - <b>Discrete</b> or <b>Continuous</b>

# %% [markdown]
# Discrete Features:

# %%
# filtering out discrete features.
print("Numerical Features with their unique value counts:")
for feature in numerical_features:
    print(f"{feature}: {len(tr_data[feature].unique())}")

#suppose discrete variables will have less number of unique values. we will take the threshold value = 25 here
discrete_features = [feature for feature in numerical_features if len(tr_data[feature].unique()) < 25 and feature not in temporal_features]

print(f'\nDiscrete Features:\n{discrete_features}\nCount: {len(discrete_features)}')
# Out:
# Numerical Features with their unique value counts:
# MSSubClass: 15
# LotFrontage: 111
# LotArea: 1073
# OverallQual: 10
# OverallCond: 9
# MasVnrArea: 328
# BsmtFinSF1: 637
# BsmtFinSF2: 144
# BsmtUnfSF: 780
# TotalBsmtSF: 721
# 1stFlrSF: 753
# 2ndFlrSF: 417
# LowQualFinSF: 24
# GrLivArea: 861
# BsmtFullBath: 4
# BsmtHalfBath: 3
# FullBath: 4
# HalfBath: 3
# BedroomAbvGr: 8
# KitchenAbvGr: 4
# TotRmsAbvGrd: 12
# Fireplaces: 4
# GarageCars: 5
# GarageArea: 441
# WoodDeckSF: 274
# OpenPorchSF: 202
# EnclosedPorch: 120
# 3SsnPorch: 20
# ScreenPorch: 76
# PoolArea: 8
# MiscVal: 21
# MoSold: 12
# SalePrice: 663
#
# Discrete Features:
# ['MSSubClass', 'OverallQual', 'OverallCond', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea', 'MiscVal', 'MoSold']
# Count: 17

# %% [markdown]
# We fond 17 out of 33 numerical features are Discrete, therefore othe 16 is Continuous variable

# %% [markdown]
# Finding out the relation between SalePrice and the Discrete Variables

# %%
for feature in discrete_features:
    data = tr_data.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Some of the Discrete Features are not related to the SalePrice Variable. However some features like "OverallQual" shows a Monotonic Relationship with SalePrice.

# %% [markdown]
# Continuous Features:

# %%
continuous_features = [feature for feature in numerical_features if feature not in discrete_features + temporal_features + ['Id']]
print(f"Continuous Feature Count: {len(continuous_features)}")
for feature in continuous_features:
    print(feature)
# Out:
# Continuous Feature Count: 16
# LotFrontage
# LotArea
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# GrLivArea
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# ScreenPorch
# SalePrice

# %% [markdown]
# <b>NOTE:</b><br>
# While solving Regression Problems its must to convert the Non-Gaussian Distribution to Guassian(Standard Normal) Distribution, otherwise the Linear Prediction Model will not work properly.<br>
# Also we need to handle the Outliers to get rid of Skewness of Distribution.

# %% [markdown]
# Analyzing relationship between Continuous Feature and SalePrice by using distribution plot like Histograms to check whether its Normal(Gaussian) Distribution or not.

# %%
for feature in continuous_features:
    data = tr_data.copy()
    plt.figure(figsize=(4,3.5))
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %% [markdown]
# We can see that some are Guassian Distribution and some are not. To make the non-guassian distributions guassian we have to apply "<b>NORMALISATION</b>"<br>
# We will use Logarithmic Transformation to Normalise the data to make all the distributions Normal distribution.<br>
# We will also handle the Outliers in Feature Engineering Section to handle the skewness issue.

# %% [markdown]
# <b>Logarithmic Transformation:</b><br>
# Used to change the Non-Normal Distribution to Normal Distribution

# %%
skewed_features = []
for feature in continuous_features:
    data = tr_data.copy()
    if 0 in data[feature].unique():
        pass
    else:
        skewed_features.append(feature)
        data[feature] = np.log(data[feature])
        data['SalePrice'] = np.log(data['SalePrice'])
        plt.figure(figsize=(4,3.5))
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %%
skewed_features
# Out:
# ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

# %% [markdown]
# Only these 5 feature under Continuous Features do not have 0 as a unique value, other 11 features have 0 as unique value so that they are not normalised and plotted.

# %% [markdown]
# We normalize (usign Logarithmic Scaling) this features in Feature Engineering part.

# %% [markdown]
# <h3> A.3. Outliers: </h3>

# %% [markdown]
# Finding variables that have outliers and also know the relationship between that variable and Target Variable.

# %%
for feature in continuous_features:
    data = tr_data.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column = feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# We can see that most of the continuous features have outliers.
# We will handle the outliers in the Feature Engineering section.

# %% [markdown]
# <h3> A.4. Categorical Variables & Cardinality: </h3>

# %% [markdown]
# First we will filter out the Categorical variables and store them is a list.

# %%
categorical_features = [feature for feature in tr_data.columns if tr_data[feature].dtypes == 'O']
print(f"Count of Categorical features: {len(categorical_features)}")
categorical_features
# Out:
# Count of Categorical features: 43
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %% [markdown]
# We have total 43 categorical variables.<br>
# Next we have to find out the Cardinality of the categorical variables.

# %%
for feature in categorical_features:
    print(f"Feature: {feature}, Unique Categories: {tr_data[feature].unique()}, Cardinality: {len(tr_data[feature].unique())}")
# Out:
# Feature: MSZoning, Unique Categories: ['RL' 'RM' 'C (all)' 'FV' 'RH'], Cardinality: 5
# Feature: Street, Unique Categories: ['Pave' 'Grvl'], Cardinality: 2
# Feature: Alley, Unique Categories: [nan 'Grvl' 'Pave'], Cardinality: 3
# Feature: LotShape, Unique Categories: ['Reg' 'IR1' 'IR2' 'IR3'], Cardinality: 4
# Feature: LandContour, Unique Categories: ['Lvl' 'Bnk' 'Low' 'HLS'], Cardinality: 4
# Feature: Utilities, Unique Categories: ['AllPub' 'NoSeWa'], Cardinality: 2
# Feature: LotConfig, Unique Categories: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3'], Cardinality: 5
# Feature: LandSlope, Unique Categories: ['Gtl' 'Mod' 'Sev'], Cardinality: 3
# Feature: Neighborhood, Unique Categories: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste'], Cardinality: 25
# Feature: Condition1, Unique Categories: ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe'], Cardinality: 9
# Feature: Condition2, Unique Categories: ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe'], Cardinality: 8
# Feature: BldgType, Unique Categories: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs'], Cardinality: 5
# Feature: HouseStyle, Unique Categories: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin'], Cardinality: 8
# Feature: RoofStyle, Unique Categories: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed'], Cardinality: 6
# Feature: RoofMatl, Unique Categories: ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile'], Cardinality: 8
# Feature: Exterior1st, Unique Categories: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock'], Cardinality: 15
# Feature: Exterior2nd, Unique Categories: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock'], Cardinality: 16
# Feature: MasVnrType, Unique Categories: ['BrkFace' nan 'Stone' 'BrkCmn'], Cardinality: 4
# Feature: ExterQual, Unique Categories: ['Gd' 'TA' 'Ex' 'Fa'], Cardinality: 4
# Feature: ExterCond, Unique Categories: ['TA' 'Gd' 'Fa' 'Po' 'Ex'], Cardinality: 5
# Feature: Foundation, Unique Categories: ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone'], Cardinality: 6
# Feature: BsmtQual, Unique Categories: ['Gd' 'TA' 'Ex' nan 'Fa'], Cardinality: 5
# Feature: BsmtCond, Unique Categories: ['TA' 'Gd' nan 'Fa' 'Po'], Cardinality: 5
# Feature: BsmtExposure, Unique Categories: ['No' 'Gd' 'Mn' 'Av' nan], Cardinality: 5
# Feature: BsmtFinType1, Unique Categories: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ'], Cardinality: 7
# Feature: BsmtFinType2, Unique Categories: ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ'], Cardinality: 7
# Feature: Heating, Unique Categories: ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor'], Cardinality: 6
# Feature: HeatingQC, Unique Categories: ['Ex' 'Gd' 'TA' 'Fa' 'Po'], Cardinality: 5
# Feature: CentralAir, Unique Categories: ['Y' 'N'], Cardinality: 2
# Feature: Electrical, Unique Categories: ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan], Cardinality: 6
# Feature: KitchenQual, Unique Categories: ['Gd' 'TA' 'Ex' 'Fa'], Cardinality: 4
# Feature: Functional, Unique Categories: ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev'], Cardinality: 7
# Feature: FireplaceQu, Unique Categories: [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po'], Cardinality: 6
# Feature: GarageType, Unique Categories: ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types'], Cardinality: 7
# Feature: GarageFinish, Unique Categories: ['RFn' 'Unf' 'Fin' nan], Cardinality: 4
# Feature: GarageQual, Unique Categories: ['TA' 'Fa' 'Gd' nan 'Ex' 'Po'], Cardinality: 6
# Feature: GarageCond, Unique Categories: ['TA' 'Fa' nan 'Gd' 'Po' 'Ex'], Cardinality: 6
# Feature: PavedDrive, Unique Categories: ['Y' 'N' 'P'], Cardinality: 3
# Feature: PoolQC, Unique Categories: [nan 'Ex' 'Fa' 'Gd'], Cardinality: 4
# Feature: Fence, Unique Categories: [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw'], Cardinality: 5
# Feature: MiscFeature, Unique Categories: [nan 'Shed' 'Gar2' 'Othr' 'TenC'], Cardinality: 5
# Feature: SaleType, Unique Categories: ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth'], Cardinality: 9
# Feature: SaleCondition, Unique Categories: ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family'], Cardinality: 6

# %% [markdown]
# Let's find out the relationship between Categorical Features and Target Feature

# %%
for feature in categorical_features:
    data = tr_data.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# From the above graphs we can see that which categorical features are getting the highest values.

# %% [markdown]
# ---

# %% [markdown]
# <h2> B. Feature Engineering </h2>

# %% [markdown]
# **We will perform the following Feature Engineering:**
# - Train-Test Split
# - Handling missing values
#     - Categorical features
#     - Numerical features
# - Handling Temporal (DateTime) features
# - Handling Skewness using Log Normal Transformation (Generally for Numerical Variable) (Normalization)
# - Handling Rare Categorical features (Reduction of Cardinality)
# - Feature Scaling (Converting Categorical features -> Numerical features)

# %% [markdown]
# <h3> B.1. Train-Test Split: </h3>

# %% [markdown]
# Most important first step of Feature Engineering is to split the data in training_dataset and test_dataset. However here we have the training_dataset and test_dataset separately. We have to apply feature engineering to both training and test datasets.

# %% [markdown]
# Below is the code example to perform train test split. Commenting it out as we don't need it in this model training.

# %%
'''
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tr_data, tr_data['SalePrice'], test_size = 0.1, random_state = 0)
'''
# Out:
# "\nfrom sklearn.model_selection import train_test_split\nX_train, X_test, y_train, y_test = train_test_split(tr_data, tr_data['SalePrice'], test_size = 0.1, random_state = 0)\n"

# %% [markdown]
# <h3> B.2. Handling Missing Values: </h3>

# %% [markdown]
# <h4>B.2.1. Categorical Feature:</h4>

# %%
cat_features_nan = [feature for feature in tr_data.columns if tr_data[feature].isnull().sum() > 1 and tr_data[feature].dtypes == 'O']

for feature in cat_features_nan:
    print(f"{feature}: {np.round(tr_data[feature].isnull().mean()*100,4)}%")
# Out:
# Alley: 93.7671%
# MasVnrType: 59.726%
# BsmtQual: 2.5342%
# BsmtCond: 2.5342%
# BsmtExposure: 2.6027%
# BsmtFinType1: 2.5342%
# BsmtFinType2: 2.6027%
# FireplaceQu: 47.2603%
# GarageType: 5.5479%
# GarageFinish: 5.5479%
# GarageQual: 5.5479%
# GarageCond: 5.5479%
# PoolQC: 99.5205%
# Fence: 80.7534%
# MiscFeature: 96.3014%

# %% [markdown]
# Will replace those missing values of the Categorical features with new label("Missing").

# %%
def replace_nan_cat_features(tr_data, cat_features_nan):
    data = tr_data.copy()
    data[cat_features_nan] = data[cat_features_nan].fillna('Missing')
    return data

tr_data = replace_nan_cat_features(tr_data, cat_features_nan)

tr_data[cat_features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# We can see that all the categorical features have zero null values.

# %% [markdown]
# <h4>B.2.2. Numerical Feature:</h4>

# %%
num_features_nan = [feature for feature in numerical_features if tr_data[feature].isnull().sum()]

for feature in num_features_nan:
    print(f"{feature}: {np.round(tr_data[feature].isnull().mean()*100,4)}%")
# Out:
# LotFrontage: 17.7397%
# MasVnrArea: 0.5479%

# %% [markdown]
# We will replace the nan values with median()

# %%
for feature in num_features_nan:
    # calculating median value since there are outliers
    median_val = tr_data[feature].median()
    
    # creating a new feature to capture nan values
    tr_data[feature+'_nan'] = np.where(tr_data[feature].isnull(), 1, 0) # to keep info about the records which were nan value before replacing them with median value
    tr_data[feature].fillna(median_val, inplace = True)
    
tr_data[num_features_nan].isnull().sum()
# Out:
# /tmp/ipykernel_17/218570365.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tr_data[feature].fillna(median_val, inplace = True)
# /tmp/ipykernel_17/218570365.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tr_data[feature].fillna(median_val, inplace = True)
# LotFrontage    0
# MasVnrArea     0
# dtype: int64

# %% [markdown]
# <h3> B.3. Handling Temporal (DateTime) Variables: </h3>

# %% [markdown]
# We will take all the Temporal features except 'YearSold' and convert them from year value to count of years by subtracting from the YearSold value

# %%
temporal_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    tr_data[feature] = tr_data['YrSold'] - tr_data[feature]
    
tr_data[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# <h3> B.4. Handling Skewness of Numerical Features: </h3>

# %% [markdown]
# Some of the continuous numerical features have skewed values and we have filtered them out and stored in a list named 'skewed_features'.<br>Now we will turn this features into Normal distributions using Log Normal Transformation.

# %%
# Before Normalization
tr_data[skewed_features]
# Out:
#       LotFrontage  LotArea  1stFlrSF  GrLivArea  SalePrice
# 0            65.0     8450       856       1710     208500
# 1            80.0     9600      1262       1262     181500
# 2            68.0    11250       920       1786     223500
# 3            60.0     9550       961       1717     140000
# 4            84.0    14260      1145       2198     250000
# ...           ...      ...       ...        ...        ...
# 1455         62.0     7917       953       1647     175000
# 1456         85.0    13175      2073       2073     210000
# 1457         66.0     9042      1188       2340     266500
# 1458         68.0     9717      1078       1078     142125
# 1459         75.0     9937      1256       1256     147500
#
# [1460 rows x 5 columns]

# %%
for feature in skewed_features:
    tr_data[feature] = np.log(tr_data[feature])

# %%
# After Normalization
tr_data[skewed_features]
# Out:
#       LotFrontage   LotArea  1stFlrSF  GrLivArea  SalePrice
# 0        4.174387  9.041922  6.752270   7.444249  12.247694
# 1        4.382027  9.169518  7.140453   7.140453  12.109011
# 2        4.219508  9.328123  6.824374   7.487734  12.317167
# 3        4.094345  9.164296  6.867974   7.448334  11.849398
# 4        4.430817  9.565214  7.043160   7.695303  12.429216
# ...           ...       ...       ...        ...        ...
# 1455     4.127134  8.976768  6.859615   7.406711  12.072541
# 1456     4.442651  9.486076  7.636752   7.636752  12.254863
# 1457     4.189655  9.109636  7.080026   7.757906  12.493130
# 1458     4.219508  9.181632  6.982863   6.982863  11.864462
# 1459     4.317488  9.204020  7.135687   7.135687  11.901583
#
# [1460 rows x 5 columns]

# %% [markdown]
# Transformed skewed continuous numerical features into Normal Distribution.

# %% [markdown]
# <h3> B.5. Handling Rare and Reducing Cardinality of Categorical Features: </h3>

# %% [markdown]
# We can skip categories that are less frequent among other categories in a feature as they are not contributing towards the prediction.<br>We will convert those rare categories into a 'new_label'/'other'.<br><br>First filter out the categorical features, that we already did and stored in a list - 'categorical_features'.

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(categorical_features)
# Out:
# 43

# %% [markdown]
# Now we will find out the percentage of occurance of each category for all the categorical features. we will replace those features whose frequency is 10% ro less than 10%

# %%
for feature in categorical_features:
    temp = tr_data.groupby(feature)['SalePrice'].count()/len(tr_data)
    temp_df = temp[temp > 0.01].index
    tr_data[feature] = np.where(tr_data[feature].isin(temp_df), tr_data[feature], 'rare_var')

# %%
tr_data[categorical_features]
# Out:
#      MSZoning Street    Alley LotShape LandContour Utilities LotConfig  \
# 0          RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1          RL   Pave  Missing      Reg         Lvl    AllPub       FR2
# 2          RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 3          RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 4          RL   Pave  Missing      IR1         Lvl    AllPub       FR2
# ...       ...    ...      ...      ...         ...       ...       ...
# 1455       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1456       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1457       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1458       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1459       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1          Gtl     rare_var      Feedr       Norm     1Fam     1Story
# 2          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3          Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4          Gtl      NoRidge       Norm       Norm     1Fam     2Story
# ...        ...          ...        ...        ...      ...        ...
# 1455       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1456       Gtl       NWAmes       Norm       Norm     1Fam     1Story
# 1457       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 1458       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 1459       Gtl      Edwards       Norm       Norm     1Fam     1Story
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# 0        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 1        Gable  CompShg     MetalSd     MetalSd    Missing        TA
# 2        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 3        Gable  CompShg     Wd Sdng     Wd Shng    Missing        TA
# 4        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# ...        ...      ...         ...         ...        ...       ...
# 1455     Gable  CompShg     VinylSd     VinylSd    Missing        TA
# 1456     Gable  CompShg     Plywood     Plywood      Stone        TA
# 1457     Gable  CompShg     CemntBd     CmentBd    Missing        Ex
# 1458       Hip  CompShg     MetalSd     MetalSd    Missing        TA
# 1459     Gable  CompShg     HdBoard     HdBoard    Missing        Gd
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0           TA      PConc       Gd       TA           No          GLQ
# 1           TA     CBlock       Gd       TA           Gd          ALQ
# 2           TA      PConc       Gd       TA           Mn          GLQ
# 3           TA     BrkTil       TA       Gd           No          ALQ
# 4           TA      PConc       Gd       TA           Av          GLQ
# ...        ...        ...      ...      ...          ...          ...
# 1455        TA      PConc       Gd       TA           No          Unf
# 1456        TA     CBlock       Gd       TA           No          ALQ
# 1457        Gd   rare_var       TA       Gd           No          GLQ
# 1458        TA     CBlock       TA       TA           Mn          GLQ
# 1459        TA     CBlock       TA       TA           No          BLQ
#
#      BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# 0             Unf    GasA        Ex          Y      SBrkr          Gd
# 1             Unf    GasA        Ex          Y      SBrkr          TA
# 2             Unf    GasA        Ex          Y      SBrkr          Gd
# 3             Unf    GasA        Gd          Y      SBrkr          Gd
# 4             Unf    GasA        Ex          Y      SBrkr          Gd
# ...           ...     ...       ...        ...        ...         ...
# 1455          Unf    GasA        Ex          Y      SBrkr          TA
# 1456          Rec    GasA        TA          Y      SBrkr          TA
# 1457          Unf    GasA        Ex          Y      SBrkr          Gd
# 1458          Rec    GasA        Gd          Y      FuseA          Gd
# 1459          LwQ    GasA        Gd          Y      SBrkr          TA
#
#      Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0           Typ     Missing     Attchd          RFn         TA         TA
# 1           Typ          TA     Attchd          RFn         TA         TA
# 2           Typ          TA     Attchd          RFn         TA         TA
# 3           Typ          Gd     Detchd          Unf         TA         TA
# 4           Typ          TA     Attchd          RFn         TA         TA
# ...         ...         ...        ...          ...        ...        ...
# 1455        Typ          TA     Attchd          RFn         TA         TA
# 1456       Min1          TA     Attchd          Unf         TA         TA
# 1457        Typ          Gd     Attchd          RFn         TA         TA
# 1458        Typ     Missing     Attchd          Unf         TA         TA
# 1459        Typ     Missing     Attchd          Fin         TA         TA
#
#      PavedDrive   PoolQC    Fence MiscFeature SaleType SaleCondition
# 0             Y  Missing  Missing     Missing       WD        Normal
# 1             Y  Missing  Missing     Missing       WD        Normal
# 2             Y  Missing  Missing     Missing       WD        Normal
# 3             Y  Missing  Missing     Missing       WD       Abnorml
# 4             Y  Missing  Missing     Missing       WD        Normal
# ...         ...      ...      ...         ...      ...           ...
# 1455          Y  Missing  Missing     Missing       WD        Normal
# 1456          Y  Missing    MnPrv     Missing       WD        Normal
# 1457          Y  Missing    GdPrv        Shed       WD        Normal
# 1458          Y  Missing  Missing     Missing       WD        Normal
# 1459          Y  Missing  Missing     Missing       WD        Normal
#
# [1460 rows x 43 columns]

# %% [markdown]
# We can see that some of the data in the categorical features are converted to rare_var as their frequency is 10% or less than that.

# %%
for feature in categorical_features:
    high_cardinality_cont_features = [feature for feature in categorical_features if len(tr_data[feature].unique()) > 5]
    print(f"{feature}: {tr_data[feature].unique()}; Cardinality: {len(tr_data[feature].unique())}")
# Out:
# MSZoning: ['RL' 'RM' 'rare_var' 'FV' 'RH']; Cardinality: 5
# Street: ['Pave' 'rare_var']; Cardinality: 2
# Alley: ['Missing' 'Grvl' 'Pave']; Cardinality: 3
# LotShape: ['Reg' 'IR1' 'IR2' 'rare_var']; Cardinality: 4
# LandContour: ['Lvl' 'Bnk' 'Low' 'HLS']; Cardinality: 4
# Utilities: ['AllPub' 'rare_var']; Cardinality: 2
# LotConfig: ['Inside' 'FR2' 'Corner' 'CulDSac' 'rare_var']; Cardinality: 5
# LandSlope: ['Gtl' 'Mod' 'rare_var']; Cardinality: 3
# Neighborhood: ['CollgCr' 'rare_var' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'Blmngtn'
#  'BrDale' 'SWISU']; Cardinality: 23
# Condition1: ['Norm' 'Feedr' 'PosN' 'Artery' 'rare_var' 'RRAn']; Cardinality: 6
# Condition2: ['Norm' 'rare_var']; Cardinality: 2
# BldgType: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']; Cardinality: 5
# HouseStyle: ['2Story' '1Story' '1.5Fin' 'rare_var' 'SFoyer' 'SLvl']; Cardinality: 6
# RoofStyle: ['Gable' 'Hip' 'rare_var']; Cardinality: 3
# RoofMatl: ['CompShg' 'rare_var']; Cardinality: 2
# Exterior1st: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'rare_var']; Cardinality: 11
# Exterior2nd: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'rare_var']; Cardinality: 11
# MasVnrType: ['BrkFace' 'Missing' 'Stone' 'BrkCmn']; Cardinality: 4
# ExterQual: ['Gd' 'TA' 'Ex' 'rare_var']; Cardinality: 4
# ExterCond: ['TA' 'Gd' 'Fa' 'rare_var']; Cardinality: 4
# Foundation: ['PConc' 'CBlock' 'BrkTil' 'rare_var' 'Slab']; Cardinality: 5
# BsmtQual: ['Gd' 'TA' 'Ex' 'Missing' 'Fa']; Cardinality: 5
# BsmtCond: ['TA' 'Gd' 'Missing' 'Fa' 'rare_var']; Cardinality: 5
# BsmtExposure: ['No' 'Gd' 'Mn' 'Av' 'Missing']; Cardinality: 5
# BsmtFinType1: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'Missing' 'LwQ']; Cardinality: 7
# BsmtFinType2: ['Unf' 'BLQ' 'Missing' 'ALQ' 'Rec' 'LwQ' 'rare_var']; Cardinality: 7
# Heating: ['GasA' 'GasW' 'rare_var']; Cardinality: 3
# HeatingQC: ['Ex' 'Gd' 'TA' 'Fa' 'rare_var']; Cardinality: 5
# CentralAir: ['Y' 'N']; Cardinality: 2
# Electrical: ['SBrkr' 'FuseF' 'FuseA' 'rare_var']; Cardinality: 4
# KitchenQual: ['Gd' 'TA' 'Ex' 'Fa']; Cardinality: 4
# Functional: ['Typ' 'Min1' 'rare_var' 'Min2' 'Mod']; Cardinality: 5
# FireplaceQu: ['Missing' 'TA' 'Gd' 'Fa' 'Ex' 'Po']; Cardinality: 6
# GarageType: ['Attchd' 'Detchd' 'BuiltIn' 'rare_var' 'Missing' 'Basment']; Cardinality: 6
# GarageFinish: ['RFn' 'Unf' 'Fin' 'Missing']; Cardinality: 4
# GarageQual: ['TA' 'Fa' 'rare_var' 'Missing']; Cardinality: 4
# GarageCond: ['TA' 'Fa' 'Missing' 'rare_var']; Cardinality: 4
# PavedDrive: ['Y' 'N' 'P']; Cardinality: 3
# PoolQC: ['Missing' 'rare_var']; Cardinality: 2
# Fence: ['Missing' 'MnPrv' 'GdWo' 'GdPrv' 'rare_var']; Cardinality: 5
# MiscFeature: ['Missing' 'Shed' 'rare_var']; Cardinality: 3
# SaleType: ['WD' 'New' 'COD' 'rare_var']; Cardinality: 4
# SaleCondition: ['Normal' 'Abnorml' 'Partial' 'rare_var' 'Family']; Cardinality: 5

# %%
for feature in high_cardinality_cont_features:
    print(f"{feature}: {tr_data[feature].unique()}; Cardinality: {len(tr_data[feature].unique())}")
# Out:
# Neighborhood: ['CollgCr' 'rare_var' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'Blmngtn'
#  'BrDale' 'SWISU']; Cardinality: 23
# Condition1: ['Norm' 'Feedr' 'PosN' 'Artery' 'rare_var' 'RRAn']; Cardinality: 6
# HouseStyle: ['2Story' '1Story' '1.5Fin' 'rare_var' 'SFoyer' 'SLvl']; Cardinality: 6
# Exterior1st: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'rare_var']; Cardinality: 11
# Exterior2nd: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'rare_var']; Cardinality: 11
# BsmtFinType1: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'Missing' 'LwQ']; Cardinality: 7
# BsmtFinType2: ['Unf' 'BLQ' 'Missing' 'ALQ' 'Rec' 'LwQ' 'rare_var']; Cardinality: 7
# FireplaceQu: ['Missing' 'TA' 'Gd' 'Fa' 'Ex' 'Po']; Cardinality: 6
# GarageType: ['Attchd' 'Detchd' 'BuiltIn' 'rare_var' 'Missing' 'Basment']; Cardinality: 6

# %% [markdown]
# We found out that after handling the rare categories there are features with high cardinality ( > 5).
# Now we have to reduce the Cardinality of these features.

# %% [markdown]
# <h3> B.6. Feature Scaling: </h3>

# %% [markdown]
# ---

# %% [markdown]
# <h2> C. Feature Selection </h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1> Test Dataset </h1>

# %% [markdown]
# storing test dataset into ts_data variable

# %%
ts_data = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')
ts_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd        NaN
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd        NaN
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard        NaN
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
ts_data.shape
# Out:
# (1459, 80)

# %% [markdown]
# Number of records in both Training dataset and Test dataset is same (around 1460 records).

# %% [markdown]
# **Things to do:**
# <br>Same as we did with Training dataset.
# - Missing Values analysis
# - Filtering out Numerical values
#     - Filtering out Discrete variables
#         - Relation b/w Discrete variables and Target Feature
#     - Filtering out Continuous variables
#         - Relation b/w Continuous variables and Target Feature
# - Filtering out Categorical Features
#     - Relation b/w Categorical variables and Target Feature
# - Cardinality of Categorical Features
# - Outliers
#
# <br>We will repeate all the steps from Training dataset EDA

# %% [markdown]
# <h2> X. Exploratory Data Analysis </h2>

# %% [markdown]
# <h2> Y. Feature Engineedring </h2>

# %% [markdown]
# <h2> Z. Feature Selection </h2>
